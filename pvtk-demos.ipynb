# %%
#demo for pvtkpython
import vtk
colors = vtk.vtkNamedColors()
boxWidget = vtk.vtkBoxWidget()
t = vtk.vtkTransform()
ren1 = vtk.vtkRenderer()
renWin = vtk.vtkRenderWindow()
cam1 = ren1.GetActiveCamera()
planeWidgetX = vtk.vtkImagePlaneWidget()
ipw=planeWidgetX
reslice = vtk.vtkImageReslice()
points = vtk.vtkPoints()
#iobsver=vtk.vtkInteractorObserver()

# %%
help(reslice.SetSlabNumberOfSlices)
# Out:
# Help on built-in function SetSlabNumberOfSlices:
#
# SetSlabNumberOfSlices(...) method of vtkmodules.vtkImagingCore.vtkImageReslice instance
#     V.SetSlabNumberOfSlices(int)
#     C++: virtual void SetSlabNumberOfSlices(int _arg)
#
#     Set the number of slices that will be combined to create the
#     slab.

# %%
help(points.SetPoint)
# Out:
# Help on built-in function SetPoint:
#
# SetPoint(...) method of vtkmodules.vtkCommonCore.vtkPoints instance
#     V.SetPoint(int, (float, float, float))
#     C++: void SetPoint(vtkIdType id, const double x[3])
#     V.SetPoint(int, float, float, float)
#     C++: void SetPoint(vtkIdType id, double x, double y, double z)

# %%
help(ipw.GetPlaneOrientation)
# Out:
# Help on built-in function GetPlaneOrientation:
#
# GetPlaneOrientation(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.GetPlaneOrientation() -> int
#     C++: virtual int GetPlaneOrientation()
#
#     Convenience method sets the plane orientation normal to the x, y,
#     or z axes.  Default is XAxes (0).

# %%
ss=dir(ren1)
for s in ss:
    if "camer" in s.lower():
        print(s)
help(ren1.ResetCameraClippingRange)
# Out:
# GetActiveCamera
# GetLightFollowCamera
# IsActiveCameraCreated
# LightFollowCameraOff
# LightFollowCameraOn
# MakeCamera
# ResetCamera
# ResetCameraClippingRange
# SetActiveCamera
# SetLightFollowCamera
# UpdateLightsGeometryToFollowCamera
# Help on built-in function ResetCameraClippingRange:
#
# ResetCameraClippingRange(...) method of vtkmodules.vtkRenderingOpenGL2.vtkOpenGLRenderer instance
#     V.ResetCameraClippingRange()
#     C++: virtual void ResetCameraClippingRange()
#     V.ResetCameraClippingRange([float, float, float, float, float,
#         float])
#     C++: virtual void ResetCameraClippingRange(double bounds[6])
#     V.ResetCameraClippingRange(float, float, float, float, float,
#         float)
#     C++: virtual void ResetCameraClippingRange(double xmin,
#         double xmax, double ymin, double ymax, double zmin,
#         double zmax)
#
#     Reset the camera clipping range based on the bounds of the
#     visible actors. This ensures that no props are cut off

# %%
ss=dir(ipw)
for s in ss:
    if "prop" in s.lower():
        print(s)
        #cmd=f"help(ipw.{s})"
        #eval(cmd)
    #print(s)
# Out:
# GetCursorProperty
# GetMarginProperty
# GetPlaneProperty
# GetProp3D
# GetSelectedPlaneProperty
# GetTextProperty
# GetTexturePlaneProperty
# SetCursorProperty
# SetMarginProperty
# SetPlaneProperty
# SetProp3D
# SetSelectedPlaneProperty
# SetTextProperty
# SetTexturePlaneProperty

# %%
help(ipw.GetProp3D)
#reslice=vtk.vtkImageReslice()
#help(reslice)
# Out:
# Help on built-in function GetProp3D:
#
# GetProp3D(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.GetProp3D() -> vtkProp3D
#     C++: virtual vtkProp3D *GetProp3D()
#
#     Specify a vtkProp3D around which to place the widget. This is not
#     required, but if supplied, it is used to initially position the
#     widget.

# %%
dir_s = dir(ipw)
#help(vtk.vtkTransform)
for ss in dir_s:
    if "ori" in ss.lower():
        #print(ss)
        pass
    print(ss)
# Out:
# AddObserver
# BreakOnError
# ComputeDisplayToWorld
# ComputeWorldToDisplay
# DebugOff
# DebugOn
# DisplayTextOff
# DisplayTextOn
# EnabledOff
# EnabledOn
# FastDelete
# GetAddressAsString
# GetCenter
# GetClassName
# GetColorMap
# GetCommand
# GetCurrentCursorPosition
# GetCurrentImageValue
# GetCurrentRenderer
# GetCursorData
# GetCursorDataStatus
# GetCursorProperty
# GetDebug
# GetDefaultRenderer
# GetDisplayText
# GetEnabled
# GetGlobalWarningDisplay
# GetHandleSize
# GetHandleSizeMaxValue
# GetHandleSizeMinValue
# GetInput
# GetInteraction
# GetInteractor
# GetKeyPressActivation
# GetKeyPressActivationValue
# GetLeftButtonAction
# GetLeftButtonActionMaxValue
# GetLeftButtonActionMinValue
# GetLeftButtonAutoModifier
# GetLeftButtonAutoModifierMaxValue
# GetLeftButtonAutoModifierMinValue
# GetLevel
# GetLookupTable
# GetMTime
# GetMarginProperty
# GetMarginSizeX
# GetMarginSizeXMaxValue
# GetMarginSizeXMinValue
# GetMarginSizeY
# GetMarginSizeYMaxValue
# GetMarginSizeYMinValue
# ...

# %%
help(ipw.GetPlaneOrientation)
#help(    boxWidget.PlaceWidget)
# Out:
# Help on built-in function GetPlaneOrientation:
#
# GetPlaneOrientation(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.GetPlaneOrientation() -> int
#     C++: virtual int GetPlaneOrientation()
#
#     Convenience method sets the plane orientation normal to the x, y,
#     or z axes.  Default is XAxes (0).

# %%
help(cam1.OrthogonalizeViewUp)
#dir(cam1)
# Out:
# Help on built-in function OrthogonalizeViewUp:
#
# OrthogonalizeViewUp(...) method of vtkmodules.vtkRenderingOpenGL2.vtkOpenGLCamera instance
#     V.OrthogonalizeViewUp()
#     C++: void OrthogonalizeViewUp()
#
#     Recompute the ViewUp vector to force it to be perpendicular to
#     camera->focalpoint vector.  Unless you are going to use Yaw or
#     Azimuth on the camera, there is no need to do this.

# %%
help(cam1.SetViewUp)
# Out:
# Help on built-in function SetViewUp:
#
# SetViewUp(...) method of vtkmodules.vtkRenderingOpenGL2.vtkOpenGLCamera instance
#     V.SetViewUp(float, float, float)
#     C++: void SetViewUp(double vx, double vy, double vz)
#     V.SetViewUp((float, float, float))
#     C++: void SetViewUp(const double a[3])
#
#     Set/Get the view up direction for the camera.  The default is
#     (0,1,0).

# %%
dir(renWin)
#dir(colors)
# Out:
# ['ActivateTexture',
#  'AddObserver',
#  'AddRenderer',
#  'AlphaBitPlanesOff',
#  'AlphaBitPlanesOn',
#  'BordersOff',
#  'BordersOn',
#  'BreakOnError',
#  'CaptureGL2PSSpecialProps',
#  'CheckAbortStatus',
#  'CheckInRenderStatus',
#  'ClearInRenderStatus',
#  'CopyResultFrame',
#  'DeactivateTexture',
#  'DebugOff',
#  'DebugOn',
#  'DetectDPI',
#  'DoubleBufferOff',
#  'DoubleBufferOn',
#  'DrawPixels',
#  'End',
#  'EraseOff',
#  'EraseOn',
#  'FastDelete',
#  'Finalize',
#  'Frame',
#  'FullScreenOff',
#  'FullScreenOn',
#  'GetAbortRender',
#  'GetActualSize',
#  'GetAddressAsString',
#  'GetAlphaBitPlanes',
#  'GetAnaglyphColorMask',
#  'GetAnaglyphColorSaturation',
#  'GetAnaglyphColorSaturationMaxValue',
#  'GetAnaglyphColorSaturationMinValue',
#  'GetBackBuffer',
#  'GetBackLeftBuffer',
#  'GetBackRightBuffer',
#  'GetBorders',
#  'GetBufferNeedsResolving',
#  'GetCapturingGL2PSSpecialProps',
#  'GetClassName',
#  'GetColorBufferInternalFormat',
#  'GetColorBufferSizes',
# ...

# %%
colors.GetColorNames()
# Out:
# 'alice_blue\naliceblue\nalizarin_crimson\nantique_white\nantiquewhite\naqua\naquamarine\naquamarine_medium\naureoline_yellow\nazure\nbanana\nbeige\nbisque\nblack\nblanched_almond\nblanchedalmond\nblue\nblue_light\nblue_medium\nblue_violet\nblueviolet\nbrick\nbrown\nbrown_madder\nbrown_ochre\nburlywood\nburnt_sienna\nburnt_umber\ncadet\ncadetblue\ncadmium_lemon\ncadmium_orange\ncadmium_red_deep\ncadmium_red_light\ncadmium_yellow\ncadmium_yellow_light\ncarrot\ncerulean\nchartreuse\nchocolate\nchrome_oxide_green\ncinnabar_green\ncobalt\ncobalt_green\ncobalt_violet_deep\ncold_grey\ncoral\ncoral_light\ncornflower\ncornflowerblue\ncornsilk\ncrimson\ncyan\ncyan_white\ndark_orange\ndarkblue\ndarkcyan\ndarkgoldenrod\ndarkgray\ndarkgreen\ndarkkhaki\ndarkmagenta\ndarkolivegreen\ndarkorange\ndarkorchid\ndarkred\ndarksalmon\ndarkseagreen\ndarkslateblue\ndarkslategray\ndarkturquoise\ndarkviolet\ndeep_ochre\ndeep_pink\ndeeppink\ndeepskyblue\ndim_grey\ndimgray\ndodger_blue\ndodgerblue\neggshell\neme
# ...

# %%
pld=vtk.vtkPolyData()
dir(pld)
# Out:
# ['ALL_PIECES_EXTENT',
#  'AddCellReference',
#  'AddObserver',
#  'AddReferenceToCell',
#  'Allocate',
#  'AllocateCellGhostArray',
#  'AllocateCopy',
#  'AllocateEstimate',
#  'AllocateExact',
#  'AllocatePointGhostArray',
#  'AllocateProportional',
#  'AttributeTypes',
#  'BOUNDING_BOX',
#  'BreakOnError',
#  'BuildCellLocator',
#  'BuildCells',
#  'BuildLinks',
#  'BuildLocator',
#  'BuildPointLocator',
#  'CELL',
#  'CELL_DATA_FIELD',
#  'CELL_DATA_VECTOR',
#  'CheckAttributes',
#  'ComputeBounds',
#  'CopyAttributes',
#  'CopyCells',
#  'CopyInformationFromPipeline',
#  'CopyInformationToPipeline',
#  'CopyStructure',
#  'Crop',
#  'DATA_EXTENT',
#  'DATA_EXTENT_TYPE',
#  'DATA_NUMBER_OF_GHOST_LEVELS',
#  'DATA_NUMBER_OF_PIECES',
#  'DATA_OBJECT',
#  'DATA_OBJECT_FIELD',
#  'DATA_PIECE_NUMBER',
#  'DATA_TIME_STEP',
#  'DATA_TYPE_NAME',
#  'DIRECTION',
#  'DataHasBeenGenerated',
#  'DebugOff',
#  'DebugOn',
#  'DeepCopy',
#  'DeleteCell',
#  'DeleteCells',
#  'DeleteLinks',
# ...

# %%
points=vtk.vtkPoints()
dir(points)
# Out:
# ['AddObserver',
#  'Allocate',
#  'BreakOnError',
#  'ComputeBounds',
#  'DebugOff',
#  'DebugOn',
#  'DeepCopy',
#  'FastDelete',
#  'GetActualMemorySize',
#  'GetAddressAsString',
#  'GetBounds',
#  'GetClassName',
#  'GetCommand',
#  'GetData',
#  'GetDataType',
#  'GetDebug',
#  'GetGlobalWarningDisplay',
#  'GetMTime',
#  'GetNumberOfGenerationsFromBase',
#  'GetNumberOfGenerationsFromBaseType',
#  'GetNumberOfPoints',
#  'GetPoint',
#  'GetPoints',
#  'GetReferenceCount',
#  'GetVoidPointer',
#  'GlobalWarningDisplayOff',
#  'GlobalWarningDisplayOn',
#  'HasObserver',
#  'Initialize',
#  'InitializeObjectBase',
#  'InsertNextPoint',
#  'InsertPoint',
#  'InsertPoints',
#  'InvokeEvent',
#  'IsA',
#  'IsTypeOf',
#  'Modified',
#  'NewInstance',
#  'Register',
#  'RemoveAllObservers',
#  'RemoveObserver',
#  'RemoveObservers',
#  'Reset',
#  'Resize',
#  'SafeDownCast',
#  'SetData',
#  'SetDataType',
#  'SetDataTypeToBit',
#  'SetDataTypeToChar',
#  'SetDataTypeToDouble',
# ...

# %%
s_all_vtk=dir(vtk)
for item in s_all_vtk:
    if "vtkImageReslice".lower() in item.lower():
        print(item)
# Out:
# vtkImageReslice
# vtkImageResliceMapper
# vtkImageResliceToColors

# %%
extvoi=vtk.vtkExtractVOI()
help(extvoi.SetVOI)
# Out:
# Help on built-in function SetVOI:
#
# SetVOI(...) method of vtkmodules.vtkImagingCore.vtkExtractVOI instance
#     V.SetVOI(int, int, int, int, int, int)
#     C++: virtual void SetVOI(int _arg1, int _arg2, int _arg3,
#         int _arg4, int _arg5, int _arg6)
#     V.SetVOI((int, int, int, int, int, int))
#     C++: virtual void SetVOI(const int _arg[6])
#
#     Specify i-j-k (min,max) pairs to extract. The resulting
#     structured points dataset can be of any topological dimension
#     (i.e., point, line, image, or volume).

# %%
v16 = vtk.vtkVolume16Reader()
v16_data=v16.GetOutput()
dir(v16_data)
# Out:
# ['ALL_PIECES_EXTENT',
#  'AddObserver',
#  'AllocateCellGhostArray',
#  'AllocatePointGhostArray',
#  'AllocateScalars',
#  'AttributeTypes',
#  'BOUNDING_BOX',
#  'BreakOnError',
#  'CELL',
#  'CELL_DATA_FIELD',
#  'CELL_DATA_VECTOR',
#  'CheckAttributes',
#  'ComputeBounds',
#  'ComputeCellId',
#  'ComputeIndexToPhysicalMatrix',
#  'ComputeInternalExtent',
#  'ComputePointId',
#  'ComputeStructuredCoordinates',
#  'CopyAndCastFrom',
#  'CopyAttributes',
#  'CopyInformationFromPipeline',
#  'CopyInformationToPipeline',
#  'CopyStructure',
#  'Crop',
#  'DATA_EXTENT',
#  'DATA_EXTENT_TYPE',
#  'DATA_NUMBER_OF_GHOST_LEVELS',
#  'DATA_NUMBER_OF_PIECES',
#  'DATA_OBJECT',
#  'DATA_OBJECT_FIELD',
#  'DATA_PIECE_NUMBER',
#  'DATA_TIME_STEP',
#  'DATA_TYPE_NAME',
#  'DIRECTION',
#  'DataHasBeenGenerated',
#  'DebugOff',
#  'DebugOn',
#  'DeepCopy',
#  'EDGE',
#  'EDGE_DATA_VECTOR',
#  'FIELD',
#  'FIELD_ACTIVE_ATTRIBUTE',
#  'FIELD_ARRAY_TYPE',
#  'FIELD_ASSOCIATION',
# ...

# %%
import time
help(time.sleep)
# Out:
# Help on built-in function sleep in module time:
#
# sleep(...)
#     sleep(seconds)
#
#     Delay execution for a given number of seconds.  The argument may be
#     a floating point number for subsecond precision.

# %%
reslice2 = vtk.vtkImageResliceToColors()
s_all_vtk=dir(reslice2)
for item in s_all_vtk:
    if "SetResliceAxes".lower() in item.lower():
        print(item)
help(reslice2.SetResliceAxesDirectionCosines)
help(reslice2.SetResliceAxes)
# Out:
# SetResliceAxes
# SetResliceAxesDirectionCosines
# SetResliceAxesOrigin
# Help on built-in function SetResliceAxesDirectionCosines:
#
# SetResliceAxesDirectionCosines(...) method of vtkmodules.vtkImagingCore.vtkImageResliceToColors instance
#     V.SetResliceAxesDirectionCosines(float, float, float, float,
#         float, float, float, float, float)
#     C++: void SetResliceAxesDirectionCosines(double x0, double x1,
#         double x2, double y0, double y1, double y2, double z0,
#         double z1, double z2)
#     V.SetResliceAxesDirectionCosines((float, float, float), (float,
#         float, float), (float, float, float))
#     C++: void SetResliceAxesDirectionCosines(const double x[3],
#         const double y[3], const double z[3])
#     V.SetResliceAxesDirectionCosines((float, float, float, float,
#         float, float, float, float, float))
#     C++: void SetResliceAxesDirectionCosines(const double xyz[9])
#
# ...

# %%
dir(planeWidgetX)
#help(planeWidgetX.SetPlaneOrientationToYAxes)
#help(planeWidgetX.EnabledOff)
help(planeWidgetX.AddObserver)
# Out:
# Help on built-in function AddObserver:
#
# AddObserver(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.AddObserver(int, function) -> int
#     C++: unsigned long AddObserver(const char *event,
#         vtkCommand *command, float priority=0.0f)
#
#     Add an event callback function(vtkObject, int) for an event type.
#     Returns a handle that can be used with RemoveEvent(int).

# %%
boxWidget = vtk.vtkBoxWidget()
help(boxWidget.AddObserver)
# Out:
# Help on built-in function AddObserver:
#
# AddObserver(...) method of vtkmodules.vtkInteractionWidgets.vtkBoxWidget instance
#     V.AddObserver(int, function) -> int
#     C++: unsigned long AddObserver(const char *event,
#         vtkCommand *command, float priority=0.0f)
#
#     Add an event callback function(vtkObject, int) for an event type.
#     Returns a handle that can be used with RemoveEvent(int).

# %%
text_representation = vtk.vtkTextRepresentation()
help(text_representation.GetPositionCoordinate)
help(text_representation.GetPosition2Coordinate)
dir(text_representation)
# Out:
# Help on built-in function GetPositionCoordinate:
#
# GetPositionCoordinate(...) method of vtkmodules.vtkInteractionWidgets.vtkTextRepresentation instance
#     V.GetPositionCoordinate() -> vtkCoordinate
#     C++: virtual vtkCoordinate *GetPositionCoordinate()
#
#     Specify opposite corners of the box defining the boundary of the
#     widget. By default, these coordinates are in the normalized
#     viewport coordinate system, with Position the lower left of the
#     outline, and Position2 relative to Position. Note that using
#     these methods are affected by the ProportionalResize flag. That
#     is, if the aspect ratio of the representation is to be preserved
#     (e.g., ProportionalResize is on), then the rectangle
#     (Position,Position2) is a bounding rectangle.
#
# Help on built-in function GetPosition2Coordinate:
#
# GetPosition2Coordinate(...) method of vtkmodules.vtkInteractionWidgets.vtkTextRepresentation instance
# ...

# %%
help(text_representation.GetProportionalResize)
# Out:
# Help on built-in function GetProportionalResize:
#
# GetProportionalResize(...) method of vtkmodules.vtkInteractionWidgets.vtkTextRepresentation instance
#     V.GetProportionalResize() -> int
#     C++: virtual vtkTypeBool GetProportionalResize()
#
#     Indicate whether resizing operations should keep the x-y
#     directions proportional to one another. Also, if
#     ProportionalResize is on, then the rectangle (Position,Position2)
#     is a bounding rectangle, and the representation will be placed in
#     the rectangle in such a way as to preserve the aspect ratio of
#     the representation.

# %%
planeWidgetX = vtk.vtkImagePlaneWidget()
prop = planeWidgetX.GetPlaneProperty()
s_dir = dir(planeWidgetX)
for item in s_dir:
    if "repre".lower() in item.lower():
        print(">"*10, item)
    print(item)
# Out:
# AddObserver
# BreakOnError
# ComputeDisplayToWorld
# ComputeWorldToDisplay
# DebugOff
# DebugOn
# DisplayTextOff
# DisplayTextOn
# EnabledOff
# EnabledOn
# FastDelete
# GetAddressAsString
# GetCenter
# GetClassName
# GetColorMap
# GetCommand
# GetCurrentCursorPosition
# GetCurrentImageValue
# GetCurrentRenderer
# GetCursorData
# GetCursorDataStatus
# GetCursorProperty
# GetDebug
# GetDefaultRenderer
# GetDisplayText
# GetEnabled
# GetGlobalWarningDisplay
# GetHandleSize
# GetHandleSizeMaxValue
# GetHandleSizeMinValue
# GetInput
# GetInteraction
# GetInteractor
# GetKeyPressActivation
# GetKeyPressActivationValue
# GetLeftButtonAction
# GetLeftButtonActionMaxValue
# GetLeftButtonActionMinValue
# GetLeftButtonAutoModifier
# GetLeftButtonAutoModifierMaxValue
# GetLeftButtonAutoModifierMinValue
# GetLevel
# GetLookupTable
# GetMTime
# GetMarginProperty
# GetMarginSizeX
# GetMarginSizeXMaxValue
# GetMarginSizeXMinValue
# GetMarginSizeY
# GetMarginSizeYMaxValue
# GetMarginSizeYMinValue
# ...

# %%
help(planeWidgetX.SetPriority)
help(planeWidgetX.SetTextProperty)
help(planeWidgetX.SetDisplayText)
help(prop.SetColor)
# Out:
# Help on built-in function SetPriority:
#
# SetPriority(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.SetPriority(float)
#     C++: virtual void SetPriority(float _arg)
#
#     Set/Get the priority at which events are processed. This is used
#     when multiple interactor observers are used simultaneously. The
#     default value is 0.0 (lowest priority.) Note that when multiple
#     interactor observer have the same priority, then the last
#     observer added will process the event first. (Note: once the
#     SetInteractor() method has been called, changing the priority
#     does not effect event processing. You will have to
#     SetInteractor(NULL), change priority, and then
#     SetInteractor(iren) to have the priority take effect.)
#
# Help on built-in function SetTextProperty:
#
# SetTextProperty(...) method of vtkmodules.vtkInteractionWidgets.vtkImagePlaneWidget instance
#     V.SetTextProperty(vtkTextProperty)
# ...

# %%
cam1 = render.GetActiveCamera()
# Out:
# ['Error',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_copy_dispatch',
#  '_copy_immutable',
#  '_deepcopy_atomic',
#  '_deepcopy_dict',
#  '_deepcopy_dispatch',
#  '_deepcopy_list',
#  '_deepcopy_method',
#  '_deepcopy_tuple',
#  '_keep_alive',
#  '_reconstruct',
#  'copy',
#  'deepcopy',
#  'dispatch_table',
#  'error']

# %%
def abc(a):
    a=42
    return a

b = 403
print(abc(b), "~", b)
# Out:
# 42 ~ 403

# %%
def abcl(a):
    print("a=", a)
    a[0]+=42
    
b=[403]
print("~", b)
abcl(b)
print("~", b)
# Out:
# ~ [403]
# a= [403]
# ~ [445]

# %%
text = vtk.vtkTextActor()
s_dir = dir(text)
for item in s_dir:
    if "position".lower() in item.lower():
        print(">"*10, item)
    #print(item)
# Out:
# >>>>>>>>>> GetActualPosition2Coordinate
# >>>>>>>>>> GetActualPositionCoordinate
# >>>>>>>>>> GetPosition
# >>>>>>>>>> GetPosition2
# >>>>>>>>>> GetPosition2Coordinate
# >>>>>>>>>> GetPositionCoordinate
# >>>>>>>>>> SetDisplayPosition
# >>>>>>>>>> SetPosition
# >>>>>>>>>> SetPosition2

# %%
help(text.SetDisplayPosition)
help(text.SetPosition)
# Out:
# Help on built-in function SetDisplayPosition:
#
# SetDisplayPosition(...) method of vtkmodules.vtkRenderingOpenGL2.vtkOpenGLTextActor instance
#     V.SetDisplayPosition(int, int)
#     C++: void SetDisplayPosition(int, int)
#
#     Set the Prop2D's position in display coordinates.
#
# Help on built-in function SetPosition:
#
# SetPosition(...) method of vtkmodules.vtkRenderingOpenGL2.vtkOpenGLTextActor instance
#     V.SetPosition([float, float])
#     C++: virtual void SetPosition(double x[2])
#     V.SetPosition(float, float)
#     C++: virtual void SetPosition(double x, double y)
#
#     Get the PositionCoordinate instance of vtkCoordinate. This is
#     used for for complicated or relative positioning. The position
#     variable controls the lower left corner of the Actor2D

# %%
dir(colors)
# Out:
# ['AddObserver',
#  'BreakOnError',
#  'ColorExists',
#  'DebugOff',
#  'DebugOn',
#  'FastDelete',
#  'GetAddressAsString',
#  'GetClassName',
#  'GetColor',
#  'GetColor3d',
#  'GetColor3ub',
#  'GetColor4d',
#  'GetColor4ub',
#  'GetColorNames',
#  'GetColorRGB',
#  'GetCommand',
#  'GetDebug',
#  'GetGlobalWarningDisplay',
#  'GetMTime',
#  'GetNumberOfColors',
#  'GetNumberOfGenerationsFromBase',
#  'GetNumberOfGenerationsFromBaseType',
#  'GetReferenceCount',
#  'GetSynonyms',
#  'GlobalWarningDisplayOff',
#  'GlobalWarningDisplayOn',
#  'HTMLColorToRGB',
#  'HTMLColorToRGBA',
#  'HasObserver',
#  'InitializeObjectBase',
#  'InvokeEvent',
#  'IsA',
#  'IsTypeOf',
#  'Modified',
#  'NewInstance',
#  'RGBAToHTMLColor',
#  'RGBToHTMLColor',
#  'Register',
#  'RemoveAllObservers',
#  'RemoveColor',
#  'RemoveObserver',
#  'RemoveObservers',
#  'ResetColors',
#  'SafeDownCast',
#  'SetColor',
#  'SetDebug',
#  'SetGlobalWarningDisplay',
#  'SetReferenceCount',
#  'UnRegister',
# ...

# %%
all_colors = colors.GetColorNames()
print(type(all_colors))
for c in all_colors.split():
    print(c)
# Out:
# <class 'str'>
# alice_blue
# aliceblue
# alizarin_crimson
# antique_white
# antiquewhite
# aqua
# aquamarine
# aquamarine_medium
# aureoline_yellow
# azure
# banana
# beige
# bisque
# black
# blanched_almond
# blanchedalmond
# blue
# blue_light
# blue_medium
# blue_violet
# blueviolet
# brick
# brown
# brown_madder
# brown_ochre
# burlywood
# burnt_sienna
# burnt_umber
# cadet
# cadetblue
# cadmium_lemon
# cadmium_orange
# cadmium_red_deep
# cadmium_red_light
# cadmium_yellow
# cadmium_yellow_light
# carrot
# cerulean
# chartreuse
# chocolate
# chrome_oxide_green
# cinnabar_green
# cobalt
# cobalt_green
# cobalt_violet_deep
# cold_grey
# coral
# coral_light
# cornflower
# cornflowerblue
# cornsilk
# crimson
# cyan
# cyan_white
# dark_orange
# darkblue
# darkcyan
# darkgoldenrod
# darkgray
# darkgreen
# darkkhaki
# darkmagenta
# darkolivegreen
# darkorange
# darkorchid
# darkred
# darksalmon
# darkseagreen
# darkslateblue
# darkslategray
# darkturquoise
# darkviolet
# deep_ochre
# ...
